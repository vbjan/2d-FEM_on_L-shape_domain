# %%
from numpy import *
from pylab import *

import matplotlib.tri
from math import atan2

import sys

try:
    basename = sys.argv[1]
except:
    basename = "Lshape"
	
vertices = loadtxt("Lshape_vertices.txt")
indices = loadtxt("Lshape_triangles.txt")
values = loadtxt("Lshape_values.txt")

print("using %d vertices" % len(vertices))

grid = matplotlib.tri.Triangulation( vertices[:,0], vertices[:,1], indices)

tripcolor(grid, values);

colorbar()
show()
# Out:
# using 24833 vertices
